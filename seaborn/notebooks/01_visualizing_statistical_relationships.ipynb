# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
tips = sns.load_dataset("tips")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %% [markdown]
# #### Exercise 1: Create the following image
# <img src="https://seaborn.pydata.org/_images/relational_4_0.png" width="350px"/>

# %%
g = sns.relplot(x="total_bill", y="tip", data=tips)
type(g)
# Out:
# seaborn.axisgrid.FacetGrid

# %% [markdown]
# #### Exercise 2
# <img src="https://seaborn.pydata.org/_images/relational_6_0.png" width="350px"/>

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %% [markdown]
# #### Exercise 3
# <img src="https://seaborn.pydata.org/_images/relational_8_0.png" width="600px"/>

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="smoker", data=tips)

# %% [markdown]
# #### Exercise 4
# <img src="https://seaborn.pydata.org/_images/relational_12_0.png" width="600px"/>

# %%
sns.relplot(x="total_bill", y="tip", hue="size", style="smoker", data=tips)
